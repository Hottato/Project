# %% [markdown]
# * 7월13일 절삭품 마모 확인

# %%
import numpy as np, cv2
import matplotlib.pylab as plt
import os

# %%
# 폴더 경로
folder_path = "C:/Users/31083/Documents/GitHub/Project/CNC_YOLOV8_Segmodel/normal_maybe"

image_files = os.listdir(folder_path)

images = []
for file_name in image_files:
    file_path = os.path.join(folder_path, file_name)
    image = cv2.imread(file_path, cv2.IMREAD_COLOR)

    images.append(image)

# %%
for i in range(len(images)):
    
               
    plt.imshow(float(images[i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       1 for i in range(len(images)):
# ----> 4     plt.imshow(float(images[i]))
#
# TypeError: float() argument must be a string or a number, not 'NoneType'

# %%
# t_image=cv2.imread("/content/drive/MyDrive/cnn_cnc/all_blur/T (1).jpg",cv2.IMREAD_GRAYSCALE)
nor_1=cv2.imread("C:/Users/31083/Documents/GitHub/Project/CNC_YOLOV8_Segmodel/normal_maybe/1.jpg")
nor_2=cv2.imread("C:/Users/31083/Documents/GitHub/Project/CNC_YOLOV8_Segmodel/normal_maybe/2.jpg")
nor_3=cv2.imread("C:/Users/31083/Documents/GitHub/Project/CNC_YOLOV8_Segmodel/normal_maybe/3.jpg")
nor_4=cv2.imread("C:/Users/31083/Documents/GitHub/Project/CNC_YOLOV8_Segmodel/normal_maybe/4.jpg")
plt.imshow(nor_4)

# %%
from PIL import Image

image = Image.open(file_path)

# %%
image_array = np.array(image)

# %%
plt.imshow(image_array)
plt.show()
