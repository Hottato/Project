# %% [markdown]
# # dexined

# %%
import numpy as np, cv2
import matplotlib.pylab as plt
import os
import cv2
import kornia

# %%
os.chdir(r'C:\\Users\\31083\\Documents\\GitHub\\Project\\CNC_YOLOV8_Segmodel\\Code\\DexiNed')

# !python main.py

file_path = r"C:\Users\31083\Documents\GitHub\Project\CNC_YOLOV8_Segmodel\Code\DexiNed\result\BIPED2CLASSIC\avg\Wear (21).png"

image = cv2.imread(file_path)

plt.imshow(image)

save_path = r"C:\Users\31083\Documents\GitHub\Project\CNC_YOLOV8_Segmodel\Image\dexi_result\11.png"

# 이미지 저장
cv2.imwrite(save_path, image)
# Out:
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# actual size: (480, 640, 3), target size: (512, 512)
# ...
