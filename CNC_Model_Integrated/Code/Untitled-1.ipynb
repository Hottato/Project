# %%
pip install ipython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
# !pip install numpy
# !pip install joblib
# !pip install matplotlib
# !pip install lightgbm
# !pip install bayes_opt
# !pip install scikit-learn
# Out:
# ...
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    --------------------------------------- 302.2/302.2 kB 18.2 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/4d/9c/65830d4a56c47f5283eaa244dc1228c5da9c844a9f999ebcc2e69bf6cc65/matplotlib-3.7.2-cp311-cp311-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/16/09/989b982322439faa4bafffcd669e6f942b38fee897c2664c987bcd091dec/contourpy-1.1.0-cp311-cp311-win_amd64.whl.metadata
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...

# %%
# !pip install absl-py==1.4.0
# !pip install anyio==3.5.0
# !pip install appdirs==1.4.4
# !pip install argon2-cffi==21.3.0
# !pip install argon2-cffi-bindings==21.2.0
# !pip install astor==0.8.1
# !pip install asttokens==2.0.5
# !pip install astunparse==1.6.3
# !pip install attrs==22.1.0
# !pip install babel==2.11.0
# !pip install backcall==0.2.0
# !pip install bayesian-optimization==1.4.3
# !pip install beautifulsoup4==4.12.2
# !pip install bleach==4.1.0
# !pip install blis==0.7.9
# !pip install brotlipy==0.7.0
# !pip install ca-certificates==2023.01.10
# !pip install cachetools==5.3.0
# !pip install catalogue==2.0.8
# !pip install certifi==2022.12.7
# !pip install cffi==1.15.1
# !pip install chardet==4.0.0
# !pip install charset-normalizer==2.0.4
# !pip install click==8.1.3
# !pip install colorama==0.4.6
# !pip install coloredlogs==15.0.1
# !pip install comm==0.1.2
# !pip install confection==0.0.4
# !pip install contourpy==1.0.7
# !pip install cryptography==39.0.1
# !pip install cycler==0.11.0
# !pip install cymem==2.0.7
# !pip install debugpy==1.5.1
# !pip install decorator==5.1.1
# !pip install defusedxml==0.7.1
# !pip install digraph==0.1.4
# !pip install distlib==0.3.7
# !pip install docker-pycreds==0.4.0
# !pip install entrypoints==0.4
# !pip install executing==0.8.3
# !pip install fastai==2.7.12
# !pip install fastcore==1.5.29
# !pip install fastdownload==0.0.7
# !pip install fastprogress==1.0.3
# !pip install filelock==3.12.2
# !pip install flatbuffers==23.5.9
# !pip install fonttools==4.39.4
# !pip install fsspec==2023.4.0
# !pip install gast==0.4.0
# !pip install gitdb==4.0.10
# !pip install gitpython==3.1.31
# !pip install google-auth==2.18.1
# !pip install google-auth-oauthlib==1.0.0
# !pip install google-pasta==0.2.0
# !pip install grpcio==1.54.2
# !pip install h11==0.14.0
# !pip install h5py==3.8.0
# !pip install httpcore==0.17.3
# !pip install httpx==0.24.1
# !pip install humanfriendly==10.0
# !pip install idna==2.10
# !pip install importlib-metadata==6.0.0
# !pip install importlib-resources==5.12.0
# !pip install importlib_metadata==6.0.0
# !pip install ipykernel==6.19.2
# !pip install ipython==8.12.0
# !pip install ipython_genutils==0.2.0
# !pip install jax==0.4.10
# !pip install jedi==0.18.1
# !pip install jinja2==3.1.2
# !pip install joblib==1.2.0
# !pip install json5==0.9.6
# !pip install jsonschema==4.17.3
# !pip install jupyter_client==8.1.0
# !pip install jupyter_core==5.3.0
# !pip install jupyter_server==1.23.4
# !pip install jupyterlab==3.5.3
# !pip install jupyterlab_pygments==0.1.2
# !pip install jupyterlab_server==2.22.0
# !pip install keras==2.12.0
# !pip install kiwisolver==1.4.4
# !pip install kornia==0.6.12
# !pip install langcodes==3.3.0
# !pip install libclang==16.0.0
# !pip install libiconv==1.16
# !pip install libsodium==1.0.18
# !pip install libxml2==2.10.3
# !pip install libxslt==1.1.37
# !pip install lightgbm==4.0.0
# !pip install lightning-utilities==0.9.0
# !pip install lxml==4.9.2
# !pip install markdown==3.4.3
# !pip install markdown-it-py==3.0.0
# !pip install markupsafe==2.1.1
# !pip install matplotlib==3.7.2
# !pip install matplotlib-inline==0.1.6
# !pip install mdurl==0.1.2
# !pip install mistune==0.8.4
# !pip install ml-dtypes==0.1.0
# !pip install mpmath==1.3.0
# !pip install murmurhash==1.0.9
# !pip install nbclassic==0.5.5
# !pip install nbclient==0.5.13
# !pip install nbconvert==6.5.4
# !pip install nbformat==5.7.0
# !pip install nest-asyncio==1.5.6
# !pip install networkx==3.1
# !pip install nltk==3.8.1
# !pip install notebook==6.5.4
# !pip install notebook-shim==0.2.2
# !pip install numpy==1.23.5
# !pip install oauthlib==3.2.2
# !pip install onnx==1.14.0
# !pip install onnx-graphsurgeon==0.3.27
# !pip install onnx2tf==1.14.5
# !pip install onnxruntime-gpu==1.15.1
# !pip install onnxsim==0.4.33
# !pip install opencv-python==4.7.0.72
# !pip install openssl==1.1.1t
# !pip install opt-einsum==3.3.0
# !pip install packaging==23.0
# !pip install paddle-bfloat==0.1.7
# !pip install paddlepaddle==2.5.0
# !pip install pandas==2.0.1
# !pip install pandocfilters==1.5.0
# !pip install parso==0.8.3
# !pip install pathtools==0.1.2
# !pip install pathy==0.10.1
# !pip install pickleshare==0.7.5
# !pip install pillow==9.5.0
# !pip install pip==23.0.1
# !pip install pipenv==2023.8.23
# !pip install platformdirs==3.10.0
# !pip install plotly==5.15.0
# !pip install preshed==3.0.8
# !pip install prometheus_client==0.14.1
# !pip install prompt-toolkit==3.0.36
# !pip install protobuf==4.23.1
# !pip install psutil==5.9.0
# !pip install pure_eval==0.2.2
# !pip install pyasn1==0.5.0
# !pip install pyasn1-modules==0.3.0
# !pip install pybind11==2.11.1
# !pip install pycparser==2.21
# !pip install pydantic==1.10.8
# !pip install pygments==2.15.1
# !pip install pyopenssl==23.0.0
# !pip install pyparsing==2.4.7
# !pip install pyreadline3==3.4.1
# !pip install pyrsistent==0.18.0
# !pip install pysocks==1.7.1
# !pip install python==3.9.12
# !pip install python-dateutil==2.8.2
# !pip install python-dotenv==1.0.0
# !pip install python-fastjsonschema==2.16.2
# !pip install python-graphviz==0.20.1
# !pip install pytz==2022.7
# !pip install pywin32==305
# !pip install pywinpty==2.0.10
# !pip install pyyaml==6.0
# !pip install pyzmq==25.0.2
# !pip install regex==2023.8.8
# !pip install requests==2.29.0
# !pip install requests-oauthlib==1.3.1
# !pip install requests-toolbelt==1.0.0
# !pip install rich==13.4.2
# !pip install rsa==4.9
# !pip install scikit-learn==1.2.2
# !pip install scipy==1.10.1
# !pip install seaborn==0.12.2
# !pip install send2trash==1.8.0
# !pip install sentry-sdk==1.24.0
# !pip install setproctitle==1.3.2
# !pip install setuptools==68.1.2
# !pip install six==1.16.0
# !pip install sklearn==0.0.post7
# !pip install smart-open==6.3.0
# !pip install smmap==5.0.0
# !pip install sng4onnx==1.0.1
# !pip install sniffio==1.2.0
# !pip install sounddevice==0.4.6
# !pip install soupsieve==2.4
# !pip install spacy==3.5.3
# !pip install spacy-legacy==3.0.12
# !pip install spacy-loggers==1.0.4
# !pip install sqlite==3.41.2
# !pip install srsly==2.4.6
# !pip install stack_data==0.2.0
# !pip install sympy==1.12
# !pip install tenacity==8.2.2
# !pip install tensorboard==2.12.3
# !pip install tensorboard-data-server==0.7.0
# !pip install tensorflow==2.12.0
# !pip install tensorflow-estimator==2.12.0
# !pip install tensorflow-intel==2.12.0
# !pip install tensorflow-io-gcs-filesystem==0.31.0
# !pip install termcolor==2.3.0
# !pip install terminado==0.17.1
# !pip install tflite-support==0.4.3
# !pip install thinc==8.1.10
# !pip install threadpoolctl==3.1.0
# !pip install tinycss2==1.2.1
# !pip install tomli==2.0.1
# !pip install torch==2.1.0.dev20230718+cu121
# !pip install torchaudio==2.0.2+cu118
# !pip install torchmetrics==1.0.1
# !pip install torchvision==0.15.2+cu118
# !pip install tornado==6.2
# !pip install tqdm==4.65.0
# !pip install traitlets==5.7.1
# !pip install typer==0.7.0
# !pip install typing-extensions==4.5.0
# !pip install typing_extensions==4.5.0
# !pip install tzdata==2023.3
# !pip install ultralytics==8.0.109
# !pip install urllib3==1.26.15
# !pip install vc==14.2
# !pip install virtualenv==20.24.3
# !pip install vs2015_runtime==14.27.29016
# !pip install wandb==0.15.3
# !pip install wasabi==1.1.1
# !pip install wcwidth==0.2.5
# !pip install webencodings==0.5.1
# !pip install websocket-client==0.58.0
# !pip install werkzeug==2.3.4
# !pip install wget==3.2
# !pip install wheel==0.38.4
# !pip install win_inet_pton==1.1.0
# !pip install winpty==0.4.3
# !pip install wrapt==1.14.1
# !pip install x2paddle==1.4.1
# !pip install zeromq==4.3.4
# !pip install zipp==3.11.0
# !pip install zlib==1.2.13
# Out:
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# ...
#      ---------------------------------------- 0.0/79.2 kB ? eta -:--:--
#      ---------------------------------------- 79.2/79.2 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.5 kB ? eta -:--:--
#      ---------------------------------------- 61.5/61.5 kB ? eta 0:00:00
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# ...
#      ---------------------------------------- 0.0/179.0 kB ? eta -:--:--
#      ---------------------------------------- 179.0/179.0 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#      ---------------------------------------- 118.7/118.7 kB ? eta 0:00:00
# ...
#   Attempting uninstall: asttokens
#     Found existing installation: asttokens 2.2.1
#     Uninstalling asttokens-2.2.1:
#       Successfully uninstalled asttokens-2.2.1
# ...
