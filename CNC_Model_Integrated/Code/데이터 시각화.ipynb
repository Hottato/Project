# %%
import pandas as pd
import numpy as np
import os
import matplotlib.pylab as plt

import plotly
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
# 데이터 파일 경로
data = 'C:\\Users\\31083\\Documents\\GitHub\\Project\\CNC_Model_Integrated\\Data'
data
# Out:
# 'C:\\Users\\31083\\Documents\\GitHub\\Project\\CNC_Model_Integrated\\Data'

# %%
# 데이터 프레임
cnc = []  # 데이터 프레임을 저장할 리스트

for i in range(1, 15):
    file_path = f"{data}\\2022.12.02(14번 - feed 120)\\{i}번째 데이터.csv"
    print(file_path)
    df = pd.read_csv(file_path, skiprows=1)
    cnc.append(df)
# Out:
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\1번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\2번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\3번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\4번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\5번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\6번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\7번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\8번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\9번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\10번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\11번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\12번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\13번째 데이터.csv
# C:\Users\31083\Documents\GitHub\Project\CNC_Model_Integrated\Data\2022.12.02(14번 - feed 120)\14번째 데이터.csv

# %%
# z값 0이하 만 
for i in range(len(cnc)):
    cnc[i] = cnc[i][cnc[i][' z'] <0 ]

# %%
fig = make_subplots(rows=1, cols=1)

for i in range(len(cnc)):
    

    fig.add_trace(
        go.Scatter(x=cnc[0]['hh:mm:ss:ms'], y=cnc[i][' C1'], mode='lines', name=f'{i}_C1') 
    )


fig.update_yaxes(range=[0, 10])
fig.show()

# %%
print(max(one[' C1']),max(last[' C1']))
# Out:
# 9.1542 9.6948

# %%
print((one[' C1']).mean(),(last[' C1']).mean())
# Out:
# 5.661845206812652 5.85709206426485
